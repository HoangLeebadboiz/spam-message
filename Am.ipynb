# %%
import matplotlib.pyplot as plt
import numpy as np
f = np.float64([100, 200, 300, 500, 1000, 5000, 10000, 50000, 100000])
Av = np.float64([26.4, 27.02, 27.28, 27.44, 27.36, 25.11, 21.58, 10.46, 6.02])
plt.title("Đáp ứng biên độ")
plt.xlabel("Tần số (Hz)")
plt.ylabel("20log(AV) (V/V)")
plt.plot(f, Av, "b-")
